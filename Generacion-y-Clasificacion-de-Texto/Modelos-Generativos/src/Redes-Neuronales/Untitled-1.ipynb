# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "sshleifer/tiny-gpt2"
save_dir = "./tiny-gpt2"

tok = AutoTokenizer.from_pretrained(model_name)
tok.save_pretrained(save_dir)

model = AutoModelForCausalLM.from_pretrained(model_name)
model.save_pretrained(save_dir)
# Out:
# 2025-09-27 16:17:57.590023: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-09-27 16:17:57.592829: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-09-27 16:17:57.627097: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-09-27 16:17:57.698137: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# Modelo ligero de prueba (1.1B parámetros)
model_name = "TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T"
save_dir = "./tiny-llama-1b"

# Descargar y guardar el tokenizer
print(f"🔹 Descargando tokenizer de {model_name}...")
tok = AutoTokenizer.from_pretrained(model_name)
tok.save_pretrained(save_dir)

# Descargar y guardar el modelo
print(f"🔹 Descargando modelo de {model_name}...")
model = AutoModelForCausalLM.from_pretrained(model_name)
model.save_pretrained(save_dir)

print(f"✅ Modelo y tokenizer guardados en {save_dir}")

'''
model_name = "meta-llama/Llama-3-8B"
save_dir = "./llama-3-8b"
'''
# Out:
# 🔹 Descargando tokenizer de TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T...
# 🔹 Descargando modelo de TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T...
# 2025-09-27 18:58:20.624114: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-09-27 18:58:20.624149: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-09-27 18:58:20.660260: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-09-27 18:58:20.711627: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
``
